# %% [markdown]
# # Visualize the Interface patterns

# %% [markdown]
# #### Further References:

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys

import pm4py


sys.path.append("/workspaces/university-petri-nets")
from backend.compositional_algorithm.interface_patterns.interface_patterns import IP1

# %% [markdown]
# #### 1. Interface Pattern IP-1

# %%
IP1 = IP1()

# %%
ip1_net, ip1_initial_marking, ip1_final_marking = IP1.get_net("A1")
pm4py.view_petri_net(ip1_net, ip1_initial_marking, ip1_final_marking)

ip1_net, ip1_initial_marking, ip1_final_marking = IP1.get_net("A2")
pm4py.view_petri_net(ip1_net, ip1_initial_marking, ip1_final_marking)

ip1_net, ip1_initial_marking, ip1_final_marking = IP1.get_net("IP1")
pm4py.view_petri_net(ip1_net, ip1_initial_marking, ip1_final_marking)
